# %% [markdown]
# # BRCA2 Database Bias — Full Pipeline Runner
# This notebook executes **Phases 1–5** in sequence.
#
# Before running:
# Ensure all notebooks are inside:
# ```
# /content/drive/MyDrive/BRCA2-database-bias/notebooks/
# ```

# %%
# Mount Drive if in Colab
try:
    from google.colab import drive
    drive.mount('/content/drive')
except:
    pass

# %% [markdown]
# ## Run Phase 1 – Data Download & Merge

# %%
# %run /content/drive/MyDrive/BRCA2-database-bias/notebooks/BRCA2_Colab_Phase1_DataPrep.ipynb

# %% [markdown]
# ## Run Phase 2 – South Asian Population Analysis

# %%
# %run /content/drive/MyDrive/BRCA2-database-bias/notebooks/BRCA2_Colab_Phase2_SAAnalysis.ipynb

# %% [markdown]
# ## Run Phase 3 – ACMG Frequency-Based Reclassification

# %%
# %run /content/drive/MyDrive/BRCA2-database-bias/notebooks/BRCA2_Colab_Phase3_ACMG.ipynb

# %% [markdown]
# ## Run Phase 4 – Bias Validation

# %%
# %run /content/drive/MyDrive/BRCA2-database-bias/notebooks/BRCA2_Colab_Phase4_BiasValidation.ipynb

# %% [markdown]
# ## Run Phase 5 – Publication Figures & Tables

# %%
# %run /content/drive/MyDrive/BRCA2-database-bias/notebooks/BRCA2_Colab_Phase5_PublicationFigures.ipynb
